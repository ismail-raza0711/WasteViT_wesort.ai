# %%
print("Hello, World testing")
# Out:
# Hello, World testing

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: False

# %%
import os

# 1. List all available datasets attached to this cloud session
print("Attached Datasets:", os.listdir('/kaggle/input'))

# 2. See the files inside the dataset folder
# (Replace 'dataset-folder' with the exact folder name printed above)
data_path = '/kaggle/input/datasets/feyzazkefe/trashnet'
print("Dataset Contents:", os.listdir(data_path))
# Out:
# Attached Datasets: ['datasets']
# Dataset Contents: ['dataset-resized']
